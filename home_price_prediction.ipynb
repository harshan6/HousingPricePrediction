# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("housing.csv")

# %%
dataset.shape
# Out:
# (20640, 10)

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataset.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
dataset.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
# Assuming 'data' is your DataFrame containing the dataset
unique_values = dataset['ocean_proximity'].unique()
print(unique_values)
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']

# %%
print(dataset.isnull().sum())
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
dataset['total_bedrooms'].fillna(dataset['total_bedrooms'].median(), inplace=True)

# Check for any remaining missing values
print(dataset.isnull().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
from FeatureScore import FeatureScoreCalculator

# %%
# Histograms
dataset.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='median_income', y='median_house_value', data=dataset)
plt.title('Median Income vs. Median House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.show()

# %%
# Geospatial Visualization
plt.figure(figsize=(10, 8))
sns.scatterplot(x='longitude', y='latitude', hue='median_house_value', data=dataset, palette='viridis', alpha=0.6)
plt.title('Geospatial Visualization of Median House Value')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Median House Value', loc='lower right')
plt.show()

# %%
# Bar Chart
plt.figure(figsize=(8, 6))
sns.countplot(x='ocean_proximity', data=dataset)
plt.title('Count of Houses by Ocean Proximity')
plt.xlabel('Ocean Proximity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
target="median_house_value"
calculator = FeatureScoreCalculator(dataset, target)
calculator.display_scores()
# Out:
# Feature 1: median_income - Correlation Score = 100.00
# Feature 2: latitude - Correlation Score = 20.95
# Feature 3: total_rooms - Correlation Score = 19.50
# Feature 4: housing_median_age - Correlation Score = 15.35
# Feature 5: ocean_proximity - Correlation Score = 11.88
# Feature 6: households - Correlation Score = 9.57
# Feature 7: total_bedrooms - Correlation Score = 7.19
# Feature 8: longitude - Correlation Score = 6.68
# Feature 9: population - Correlation Score = 3.58

# %%
X = dataset.drop('median_house_value', axis=1)
y = dataset['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
categorical_features = ['ocean_proximity']
numerical_features = X.columns.drop(categorical_features)

# Create column transformer with OneHotEncoder for categorical features and StandardScaler for numerical features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("\nTraining data size:", X_train.shape)
print("Testing data size:", X_test.shape)
# Out:
# Training data size: (16512, 9)
# Testing data size: (4128, 9)

# %%
# Apply preprocessing to training and testing data
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
print(X_train[:5])
# Out:
# [[ 1.00389865 -0.8400624  -1.79507596 -0.97773624 -1.0957179  -1.04760128
#   -1.1356496   0.19001247  0.          1.          0.          0.
#    0.        ]
#  [-1.43477229  0.98536392  1.85553889 -0.11850059 -0.10622101  0.05210918
#   -0.13688171  0.26931072  0.          0.          0.          1.
#    0.        ]
#  [ 0.77948108 -0.8400624  -0.20785212 -0.42167953 -0.36073103 -0.35295521
#   -0.34343319  0.02989505  1.          0.          0.          0.
#    0.        ]
#  [ 0.64981759 -0.75581196  0.74448219 -0.88856596 -0.78174293 -0.59179448
#   -0.76699444 -1.26447048  1.          0.          0.          0.
#    0.        ]
#  [ 0.59994702 -0.72304789  1.85553889 -0.12215886  0.15304621 -0.25409501
#    0.20039854 -0.36701574  1.          0.          0.          0.
#    0.        ]]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

# Show your regression model's score
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)
print(f'\nTraining score: {train_score}')
print(f'Testing score: {test_score}')
# Out:
# Training score: 0.647164612389798
# Testing score: 0.6380862497737064

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions on the testing data
y_pred = model.predict(X_test)

# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error: 49707.42799359941
# Mean Squared Error: 4719192088.227013
# R-squared: 0.6380862497737064

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define the neural network architecture
model = Sequential([
    Dense(1024, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),  # Optional: Dropout layer to reduce overfitting
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1)  # Output layer with 1 neuron for regression task
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Print a summary of the model
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 1024)           │        14,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 711,681 (2.71 MB)
#  Trainable params: 711,681 (2.71 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 23688284160.0000 - mean_absolute_error: 110020.7734 - val_loss: 4970354176.0000 - val_mean_absolute_error: 47858.0664
# Epoch 2/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4832319488.0000 - mean_absolute_error: 49603.7109 - val_loss: 4346900992.0000 - val_mean_absolute_error: 47246.1484
# Epoch 3/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4793250816.0000 - mean_absolute_error: 49230.7695 - val_loss: 4428242944.0000 - val_mean_absolute_error: 48505.4688
# Epoch 4/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4585067520.0000 - mean_absolute_error: 48450.1328 - val_loss: 4287267072.0000 - val_mean_absolute_error: 45132.4609
# Epoch 5/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4459730944.0000 - mean_absolute_error: 47229.3438 - val_loss: 4084636672.0000 - val_mean_absolute_error: 44656.5859
# Epoch 6/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4506453504.0000 - mean_absolute_error: 47374.3750 - val_loss: 4118530048.0000 - val_mean_absolute_error: 46180.1719
# Epoch 7/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4403501568.0000 - mean_absolute_error: 46863.4062 - val_loss: 3993331968.0000 - val_mean_absolute_error: 44054.3203
# Epoch 8/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4241612544.0000 - mean_absolute_error: 45978.3438 - val_loss: 3940366336.0000 - val_mean_absolute_error: 43196.1836
# Epoch 9/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 4310969856.0000 - mean_absolute_error: 46386.0000 - val_loss: 3886674176.0000 - val_mean_absolute_error: 44715.8828
# Epoch 10/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 4146356480.0000 - mean_absolute_error: 45600.0977 - val_loss: 3774509056.0000 - val_mean_absolute_error: 42486.8594
# Epoch 11/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 4030611712.0000 - mean_absolute_error: 44588.0430 - val_loss: 3762420736.0000 - val_mean_absolute_error: 42309.2930
# Epoch 12/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 4185487616.0000 - mean_absolute_error: 45673.4570 - val_loss: 3676366080.0000 - val_mean_absolute_error: 41624.5508
# Epoch 13/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 4053294336.0000 - mean_absolute_error: 44970.5039 - val_loss: 3656953344.0000 - val_mean_absolute_error: 42291.8281
# Epoch 14/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 4061846272.0000 - mean_absolute_error: 44561.5703 - val_loss: 3578479104.0000 - val_mean_absolute_error: 41724.7305
# Epoch 15/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3912851712.0000 - mean_absolute_error: 44087.6836 - val_loss: 3544879616.0000 - val_mean_absolute_error: 41604.4180
# Epoch 16/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3885652736.0000 - mean_absolute_error: 44198.9297 - val_loss: 3549772800.0000 - val_mean_absolute_error: 41566.6211
# Epoch 17/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 4093221632.0000 - mean_absolute_error: 44464.8906 - val_loss: 3726235392.0000 - val_mean_absolute_error: 41780.4805
# Epoch 18/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3907420416.0000 - mean_absolute_error: 44286.2500 - val_loss: 3453527296.0000 - val_mean_absolute_error: 40146.6055
# Epoch 19/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3927573760.0000 - mean_absolute_error: 43840.5195 - val_loss: 3334521344.0000 - val_mean_absolute_error: 39633.9805
# Epoch 20/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3817102336.0000 - mean_absolute_error: 43365.0039 - val_loss: 3332741632.0000 - val_mean_absolute_error: 40471.0234
# Epoch 21/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3831595008.0000 - mean_absolute_error: 43055.4688 - val_loss: 3542270208.0000 - val_mean_absolute_error: 40609.9844
# Epoch 22/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3758318080.0000 - mean_absolute_error: 42562.1016 - val_loss: 3343630848.0000 - val_mean_absolute_error: 40549.5273
# Epoch 23/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3720072704.0000 - mean_absolute_error: 42415.0312 - val_loss: 3357846016.0000 - val_mean_absolute_error: 39272.6250
# Epoch 24/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3638362624.0000 - mean_absolute_error: 42078.3711 - val_loss: 3256657152.0000 - val_mean_absolute_error: 39015.0898
# Epoch 25/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3782895616.0000 - mean_absolute_error: 42731.5039 - val_loss: 3201652480.0000 - val_mean_absolute_error: 39346.3828
# Epoch 26/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3615050240.0000 - mean_absolute_error: 42376.6250 - val_loss: 3356405248.0000 - val_mean_absolute_error: 39196.7539
# Epoch 27/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3669049088.0000 - mean_absolute_error: 42080.1719 - val_loss: 3174769408.0000 - val_mean_absolute_error: 38731.0859
# Epoch 28/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3537533440.0000 - mean_absolute_error: 41258.9336 - val_loss: 3194470912.0000 - val_mean_absolute_error: 39082.8164
# Epoch 29/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3457200128.0000 - mean_absolute_error: 40826.7109 - val_loss: 3150542592.0000 - val_mean_absolute_error: 39620.6602
# Epoch 30/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3593027072.0000 - mean_absolute_error: 41793.0195 - val_loss: 3170703872.0000 - val_mean_absolute_error: 39612.2812
# Epoch 31/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3474748416.0000 - mean_absolute_error: 41119.6406 - val_loss: 3149888000.0000 - val_mean_absolute_error: 38564.1641
# Epoch 32/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3444330240.0000 - mean_absolute_error: 40896.6172 - val_loss: 3057704960.0000 - val_mean_absolute_error: 37322.2852
# Epoch 33/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3466096128.0000 - mean_absolute_error: 40711.7500 - val_loss: 2992474112.0000 - val_mean_absolute_error: 37472.9141
# Epoch 34/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3605365504.0000 - mean_absolute_error: 41822.6172 - val_loss: 3048128768.0000 - val_mean_absolute_error: 37015.3359
# Epoch 35/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3449214208.0000 - mean_absolute_error: 40835.5586 - val_loss: 3049921024.0000 - val_mean_absolute_error: 38503.1797
# Epoch 36/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3429542400.0000 - mean_absolute_error: 40969.1680 - val_loss: 3012244992.0000 - val_mean_absolute_error: 37259.2930
# Epoch 37/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3343401472.0000 - mean_absolute_error: 40651.9141 - val_loss: 3019847424.0000 - val_mean_absolute_error: 38767.8828
# Epoch 38/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3280553472.0000 - mean_absolute_error: 40061.3320 - val_loss: 2941355008.0000 - val_mean_absolute_error: 36431.3594
# Epoch 39/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3235400960.0000 - mean_absolute_error: 39725.4023 - val_loss: 3007324672.0000 - val_mean_absolute_error: 36738.5312
# Epoch 40/40
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3198542336.0000 - mean_absolute_error: 39348.3086 - val_loss: 2951139840.0000 - val_mean_absolute_error: 38017.4961

# %%
# Evaluate the model
loss, mae = model.evaluate(X_test, y_test)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {loss}")
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2960646400.0000 - mean_absolute_error: 37722.8594
# Mean Absolute Error: 38017.49609375
# Mean Squared Error: 2951139840.0

# %%
# Make predictions on the testing data
y_pred = model.predict(X_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import matplotlib.pyplot as plt

# Plotting a scatter plot to compare actual vs predicted values
plt.figure(figsize=(6, 4))
plt.scatter(y_test, y_pred, color='blue', alpha=0.5)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
comparison_array = np.column_stack((y_test, y_pred))
print("real value | predicted value")
print(comparison_array[:10])
# Out:
# real value | predicted value
# [[136900.        148851.46875  ]
#  [241300.        253772.375    ]
#  [200700.        149774.625    ]
#  [ 72500.         82753.3046875]
#  [460000.        370585.21875  ]
#  [120000.        181227.6875   ]
#  [247000.        243054.5      ]
#  [336900.        381397.78125  ]
#  [339700.        307768.15625  ]
#  [265600.        252794.6875   ]]

# %%
from tensorflow.keras.models import save_model
save_model(model, 'prediction_model.keras')
